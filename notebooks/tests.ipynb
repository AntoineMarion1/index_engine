# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")

shares = ticker.get_shares_full()

print(shares)
# Out:
# 2024-12-27 00:00:00-05:00    15115799552
# 2024-12-28 00:00:00-05:00    15115799552
# 2025-01-04 00:00:00-05:00    15115799552
# 2025-01-04 00:00:00-05:00    15146300416
# 2025-01-14 00:00:00-05:00    15037899776
#                                 ...
# 2026-01-10 00:00:00-05:00    14776353000
# 2026-01-31 00:00:00-05:00    14697926000
# 2026-04-23 00:00:00-04:00    14681140000
# 2026-05-02 00:00:00-04:00    14667688000
# 2026-05-05 00:00:00-04:00    14687356000
# Length: 80, dtype: int64

# %%
import pandas as pd
prices = yf.download("AAPL")
df = pd.DataFrame(prices)
# correction MultiIndex yfinance
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

print(type(df["Close"]))
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.Series'>
# Price            Close        High         Low        Open    Volume
# 2026-04-29  269.921326  270.790520  266.794202  267.303712  30047900
# 2026-04-30  271.100250  275.745964  267.893213  270.251027  91848200
# 2026-05-01  279.882141  286.955610  278.113751  278.603290  79915400
# 2026-05-04  276.575165  280.371685  274.606977  279.402577  46668400
# 2026-05-05  283.918427  284.308082  276.245503  276.675100  49311700

# %%
import pandas as pd

year_starts = pd.date_range(start="2018-05-28", end="2020-01-24", freq="YS")
print(year_starts)
# Out:
# DatetimeIndex(['2019-01-01', '2020-01-01'], dtype='datetime64[us]', freq='YS-JAN')
